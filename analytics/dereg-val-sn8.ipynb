# %% [markdown]
# # Validators analysis SN8
# ### List of current validators

# %%
import bittensor as bt

# %%
current_metagraph = bt.metagraph(netuid=8)
current_neurons = current_metagraph.neurons
validators = [element for element in current_neurons if element.validator_trust > 0.1]

# %%
import pandas as pd
df = pd.DataFrame(validators)
print(df)

# %% [markdown]
# ### List of validators on March 6

# %%
old_metagraph = bt.subtensor('archive').metagraph(netuid=8, block=2495185)
old_neurons = old_metagraph.neurons
validators_march6 = [element for element in old_neurons if element.validator_trust > 0.1]

# %% [markdown]
# ### Deregistered validators since March 6

# %%
dereg_validators = [validator for validator in validators_march6 if validator.hotkey not in [val.hotkey for val in validators]]
len(dereg_validators)

# %% [markdown]
# ### Get the stake of the smallest active validator on each subnet

# %%
import pandas as pd
for i in range(1, 33):
    metagraph = bt.metagraph(netuid=i)
    neurons = metagraph.neurons
    subnet_df = pd.DataFrame(neurons)
    active_validators = subnet_df[subnet_df["active"] == True]
    min_stake = active_validators["stake"].min()
    print("Min stake of an active validator in SN" + str(i) + "is:" + str(min_stake))
# Out:
# 2024-04-08 17:42:48.716 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:42:48.723 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:42:48.724 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:42:49.828 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN1is:τ10,726.385984690
# 2024-04-08 17:43:07.524 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:43:07.525 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:43:07.525 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:43:08.377 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN2is:τ0.000000000
# 2024-04-08 17:43:26.597 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:43:26.598 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:43:26.598 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:43:27.373 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN3is:τ0.000000000
# 2024-04-08 17:43:46.890 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:43:46.890 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:43:46.890 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:43:47.667 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN4is:τ23,716.532120752
# 2024-04-08 17:44:12.974 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:44:12.974 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:44:12.974 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:44:13.713 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN5is:τ23,716.532120752
# 2024-04-08 17:44:30.908 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:44:30.909 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:44:30.909 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:44:31.786 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN6is:τ0.000000000
# 2024-04-08 17:44:48.176 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:44:48.176 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:44:48.176 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:44:48.979 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN7is:τ1,029.260915655
# 2024-04-08 17:45:04.142 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:45:04.143 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:45:04.143 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:45:04.988 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN8is:τ23,716.532120752
# 2024-04-08 17:45:20.378 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:45:20.379 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:45:20.379 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:45:21.261 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN9is:τ10,726.385984690
# 2024-04-08 17:45:39.324 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:45:39.325 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:45:39.325 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:45:40.041 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN10is:τ16,789.985447142
# 2024-04-08 17:45:55.207 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:45:55.208 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:45:55.208 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:45:55.996 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN11is:τ23,716.532120752
# 2024-04-08 17:46:15.535 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:46:15.535 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:46:15.535 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:46:16.285 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN12is:τ0.000000000
# 2024-04-08 17:46:30.735 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:46:30.736 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:46:30.736 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:46:31.509 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN13is:τ23,716.532120752
# 2024-04-08 17:46:49.651 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:46:49.651 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:46:49.651 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:46:50.396 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN14is:τ23,716.532120752
# 2024-04-08 17:47:10.577 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:47:10.578 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:47:10.578 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:47:11.335 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN15is:τ23,716.532120752
# 2024-04-08 17:47:26.941 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:47:26.941 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:47:26.941 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:47:27.737 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN16is:τ0.000000000
# 2024-04-08 17:47:48.782 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:47:48.784 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:47:48.785 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:47:50.371 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN17is:τ23,716.532120752
# 2024-04-08 17:48:07.127 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:48:07.127 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:48:07.127 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:48:07.871 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN18is:τ0.000000000
# 2024-04-08 17:48:24.174 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:48:24.174 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:48:24.175 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:48:25.085 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN19is:τ0.000000000
# 2024-04-08 17:48:43.635 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:48:43.635 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:48:43.635 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:48:44.428 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN20is:τ23,716.532120752
# 2024-04-08 17:49:06.273 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:49:06.274 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:49:06.274 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:49:07.190 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN21is:τ23,716.532120752
# 2024-04-08 17:49:35.593 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:49:35.601 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:49:35.602 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:49:36.886 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN22is:τ24,879.889431989
# 2024-04-08 17:49:59.460 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:49:59.461 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:49:59.461 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:50:00.760 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN23is:τ23,716.532120752
# 2024-04-08 17:50:16.913 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:50:16.913 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:50:16.913 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:50:17.716 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN24is:τ23,716.532120752
# 2024-04-08 17:50:26.828 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:50:26.828 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:50:26.828 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:50:27.569 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN25is:τ24,879.889431989
# 2024-04-08 17:50:36.075 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:50:36.076 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:50:36.076 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:50:36.892 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN26is:τ23,716.532120752
# 2024-04-08 17:50:53.427 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:50:53.427 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:50:53.427 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:50:54.231 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN27is:τ0.000000000
# 2024-04-08 17:51:15.963 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:51:15.963 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:51:15.963 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:51:16.780 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN28is:τ24,879.889431989
# 2024-04-08 17:51:33.296 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:51:33.296 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:51:33.296 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:51:34.109 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN29is:τ23,716.532120752
# 2024-04-08 17:51:46.834 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:51:46.834 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:51:46.835 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:51:47.635 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# Min stake of an active validator in SN30is:τ1,029.260915655
# 2024-04-08 17:51:58.664 |       INFO       | You are connecting to finney network with endpoint wss://entrypoint-finney.opentensor.ai:443.
# 2024-04-08 17:51:58.665 |     WARNING      | We strongly encourage running a local subtensor node whenever possible. This increases decentralization and resilience of the network.
# 2024-04-08 17:51:58.665 |     WARNING      | In a future release, local subtensor will become the default endpoint. To get ahead of this change, please run a local subtensor node and point to it.
# 2024-04-08 17:51:59.459 |       INFO       | Connected to finney network and wss://entrypoint-finney.opentensor.ai:443.
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /var/folders/dw/5hbpys7d231g5w2yrjk036600000gn/T/ipykernel_93830/357778585.py:6 in <module>      │
# │                                                                                                  │
# │ [Errno 2] No such file or directory:                                                             │
# │ '/var/folders/dw/5hbpys7d231g5w2yrjk036600000gn/T/ipykernel_93830/357778585.py'                  │
# │                                                                                                  │
# │ /Users/gustave/miniconda3/envs/bittensor/lib/python3.10/site-packages/pandas/core/frame.py:4090  │
# │ in __getitem__                                                                                   │
# │                                                                                                  │
# │    4087 │   │   if is_single_key:                                                                │
# │    4088 │   │   │   if self.columns.nlevels > 1:                                                 │
# │    4089 │   │   │   │   return self._getitem_multilevel(key)                                     │
# │ ❱  4090 │   │   │   indexer = self.columns.get_loc(key)                                          │
# │    4091 │   │   │   if is_integer(indexer):                                                      │
# │    4092 │   │   │   │   indexer = [indexer]                                                      │
# │    4093 │   │   else:                                                                            │
# │                                                                                                  │
# │ /Users/gustave/miniconda3/envs/bittensor/lib/python3.10/site-packages/pandas/core/indexes/range. │
# │ py:417 in get_loc                                                                                │
# │                                                                                                  │
# │    414 │   │   │   except ValueError as err:                                                     │
# │    415 │   │   │   │   raise KeyError(key) from err                                              │
# │    416 │   │   if isinstance(key, Hashable):                                                     │
# │ ❱  417 │   │   │   raise KeyError(key)                                                           │
# │    418 │   │   self._check_indexing_error(key)                                                   │
# │    419 │   │   raise KeyError(key)                                                               │
# │    420                                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyError: 'active'
